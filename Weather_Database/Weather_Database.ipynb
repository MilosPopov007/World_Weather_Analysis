# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mombetsu
# Processing Record 2 of Set 1 | oistins
# Processing Record 3 of Set 1 | terrace
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | jijiga
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | berezanka
# Processing Record 9 of Set 1 | keti bandar
# Processing Record 10 of Set 1 | alofi
# Processing Record 11 of Set 1 | shu
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | puerto leguizamo
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | birin
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | cockburn town
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | teknaf
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | alta floresta
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | saint anthony
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | beyneu
# Processing Record 36 of Set 1 | muttupet
# Processing Record 37 of Set 1 | faya
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | tessalit
# Processing Record 40 of Set 1 | los llanos de aridane
# Processing Record 41 of Set 1 | yanaul
# Processing Record 42 of Set 1 | ambalavao
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | agadez
# Processing Record 45 of Set 1 | ituiutaba
# Processing Record 46 of Set 1 | hambantota
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | naze
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | dogondoutchi
# Processing Record 1 of Set 2 | waingapu
# Processing Record 2 of Set 2 | palmer
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | oyo
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | lazaro cardenas
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | rawlins
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | mehamn
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | port-gentil
# Processing Record 17 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | selma
# Processing Record 20 of Set 2 | vao
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | kangaatsiaq
# Processing Record 23 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 2 | grand gaube
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | todos santos
# Processing Record 27 of Set 2 | talas
# Processing Record 28 of Set 2 | tuatapere
# Processing Record 29 of Set 2 | general higinio morinigo
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | henties bay
# Processing Record 32 of Set 2 | naples
# Processing Record 33 of Set 2 | soyo
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | talmenka
# Processing Record 40 of Set 2 | chara
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | muravlenko
# Processing Record 44 of Set 2 | rio gallegos
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | vaitape
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | ziyang
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | katobu
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | obzor
# Processing Record 10 of Set 3 | aklavik
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | luderitz
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | koungou
# Processing Record 20 of Set 3 | urumqi
# Processing Record 21 of Set 3 | kieta
# Processing Record 22 of Set 3 | udachnyy
# Processing Record 23 of Set 3 | taltal
# Processing Record 24 of Set 3 | pevek
# Processing Record 25 of Set 3 | rincon
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | vardo
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | biloela
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | nadym
# Processing Record 32 of Set 3 | prince albert
# Processing Record 33 of Set 3 | monrovia
# Processing Record 34 of Set 3 | west wendover
# Processing Record 35 of Set 3 | along
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | rawson
# Processing Record 39 of Set 3 | adre
# Processing Record 40 of Set 3 | palasa
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | balaguer
# Processing Record 44 of Set 3 | port hardy
# Processing Record 45 of Set 3 | kamenka
# Processing Record 46 of Set 3 | vaini
# Processing Record 47 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 48 of Set 3 | korla
# Processing Record 49 of Set 3 | sarangani
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 4 | constitucion
# Processing Record 3 of Set 4 | macusani
# Processing Record 4 of Set 4 | la ronge
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | tindivanam
# Processing Record 7 of Set 4 | tucson
# Processing Record 8 of Set 4 | suntar
# Processing Record 9 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | bambanglipuro
# Processing Record 12 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 4 | barrhead
# Processing Record 14 of Set 4 | requena
# Processing Record 15 of Set 4 | leh
# Processing Record 16 of Set 4 | banyo
# Processing Record 17 of Set 4 | alice springs
# Processing Record 18 of Set 4 | bredasdorp
# Processing Record 19 of Set 4 | daru
# Processing Record 20 of Set 4 | tatsinskaya
# City not found. Skipping...
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | kysyl-syr
# Processing Record 24 of Set 4 | perelyub
# Processing Record 25 of Set 4 | palana
# Processing Record 26 of Set 4 | aksay
# Processing Record 27 of Set 4 | egvekinot
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | kulhudhuffushi
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | tazovskiy
# Processing Record 33 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 4 | lodja
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | neiafu
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | haines junction
# Processing Record 40 of Set 4 | brae
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | carnduff
# Processing Record 43 of Set 4 | norwood
# Processing Record 44 of Set 4 | mattoon
# Processing Record 45 of Set 4 | college
# Processing Record 46 of Set 4 | lasa
# Processing Record 47 of Set 4 | canoinhas
# Processing Record 48 of Set 4 | sidhi
# Processing Record 49 of Set 4 | ewa beach
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | hongjiang
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | inuvik
# Processing Record 5 of Set 5 | takoradi
# Processing Record 6 of Set 5 | yulara
# Processing Record 7 of Set 5 | podor
# Processing Record 8 of Set 5 | kaitangata
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | utica
# Processing Record 11 of Set 5 | teguldet
# Processing Record 12 of Set 5 | yar-sale
# Processing Record 13 of Set 5 | san policarpo
# Processing Record 14 of Set 5 | ladario
# Processing Record 15 of Set 5 | maddarulug
# Processing Record 16 of Set 5 | matara
# Processing Record 17 of Set 5 | duz
# City not found. Skipping...
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | guarapari
# Processing Record 20 of Set 5 | cayenne
# Processing Record 21 of Set 5 | skjervoy
# Processing Record 22 of Set 5 | preetz
# Processing Record 23 of Set 5 | soligalich
# Processing Record 24 of Set 5 | el wasta
# City not found. Skipping...
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | pontianak
# Processing Record 27 of Set 5 | krasnoselkup
# Processing Record 28 of Set 5 | sepolno krajenskie
# Processing Record 29 of Set 5 | agropoli
# Processing Record 30 of Set 5 | michigan city
# Processing Record 31 of Set 5 | hithadhoo
# Processing Record 32 of Set 5 | pauini
# Processing Record 33 of Set 5 | bethel
# Processing Record 34 of Set 5 | banswada
# Processing Record 35 of Set 5 | batemans bay
# Processing Record 36 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 5 | porto novo
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | pangnirtung
# Processing Record 41 of Set 5 | yerbogachen
# Processing Record 42 of Set 5 | paracatu
# Processing Record 43 of Set 5 | gizo
# Processing Record 44 of Set 5 | olga
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | coahuayana
# Processing Record 47 of Set 5 | verkhoyansk
# Processing Record 48 of Set 5 | talnakh
# Processing Record 49 of Set 5 | carutapera
# Processing Record 50 of Set 5 | butaritari
# Processing Record 1 of Set 6 | narsaq
# Processing Record 2 of Set 6 | inhambane
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | mercedes
# Processing Record 5 of Set 6 | san joaquin
# Processing Record 6 of Set 6 | comodoro rivadavia
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | huarmey
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | fare
# Processing Record 11 of Set 6 | turinskaya sloboda
# Processing Record 12 of Set 6 | santiago de cuba
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | mount isa
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | puerto ayacucho
# Processing Record 17 of Set 6 | new norfolk
# Processing Record 18 of Set 6 | san patricio
# Processing Record 19 of Set 6 | san diego de los banos
# Processing Record 20 of Set 6 | tommot
# Processing Record 21 of Set 6 | hirara
# Processing Record 22 of Set 6 | usagara
# Processing Record 23 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 24 of Set 6 | cotonou
# Processing Record 25 of Set 6 | tweed
# Processing Record 26 of Set 6 | san ramon
# Processing Record 27 of Set 6 | moose factory
# Processing Record 28 of Set 6 | cabedelo
# Processing Record 29 of Set 6 | palaikastron
# Processing Record 30 of Set 6 | charters towers
# Processing Record 31 of Set 6 | mabaruma
# Processing Record 32 of Set 6 | ensenada
# Processing Record 33 of Set 6 | olinda
# Processing Record 34 of Set 6 | bud
# Processing Record 35 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 36 of Set 6 | camabatela
# Processing Record 37 of Set 6 | barao de melgaco
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | kourou
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | cancun
# Processing Record 43 of Set 6 | aktau
# Processing Record 44 of Set 6 | leningradskiy
# Processing Record 45 of Set 6 | moldovita
# Processing Record 46 of Set 6 | la palma
# Processing Record 47 of Set 6 | badvel
# Processing Record 48 of Set 6 | daoukro
# Processing Record 49 of Set 6 | buala
# Processing Record 50 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | torbay
# Processing Record 2 of Set 7 | formosa
# Processing Record 3 of Set 7 | nouadhibou
# Processing Record 4 of Set 7 | richards bay
# Processing Record 5 of Set 7 | katangli
# Processing Record 6 of Set 7 | conceicao do mato dentro
# Processing Record 7 of Set 7 | bosaso
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | manzhouli
# Processing Record 10 of Set 7 | manta
# Processing Record 11 of Set 7 | chumikan
# Processing Record 12 of Set 7 | fukue
# Processing Record 13 of Set 7 | reconquista
# Processing Record 14 of Set 7 | kloulklubed
# Processing Record 15 of Set 7 | vega de alatorre
# Processing Record 16 of Set 7 | bundaberg
# Processing Record 17 of Set 7 | hammerfest
# Processing Record 18 of Set 7 | mazatlan
# Processing Record 19 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | boo
# Processing Record 22 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 23 of Set 7 | malanje
# Processing Record 24 of Set 7 | wicklow
# Processing Record 25 of Set 7 | mecca
# Processing Record 26 of Set 7 | barra
# Processing Record 27 of Set 7 | aksarka
# Processing Record 28 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 7 | lublin
# Processing Record 30 of Set 7 | bengkulu
# Processing Record 31 of Set 7 | sikeston
# Processing Record 32 of Set 7 | eenhana
# Processing Record 33 of Set 7 | manzanillo
# Processing Record 34 of Set 7 | homa bay
# Processing Record 35 of Set 7 | rosetta
# Processing Record 36 of Set 7 | namibe
# Processing Record 37 of Set 7 | winslow
# Processing Record 38 of Set 7 | santander
# Processing Record 39 of Set 7 | tual
# Processing Record 40 of Set 7 | viedma
# Processing Record 41 of Set 7 | salinopolis
# Processing Record 42 of Set 7 | muroto
# Processing Record 43 of Set 7 | merauke
# Processing Record 44 of Set 7 | heihe
# Processing Record 45 of Set 7 | marawi
# Processing Record 46 of Set 7 | dedovichi
# Processing Record 47 of Set 7 | ponta delgada
# Processing Record 48 of Set 7 | port-cartier
# Processing Record 49 of Set 7 | ukiah
# Processing Record 50 of Set 7 | smithers
# Processing Record 1 of Set 8 | udon thani
# Processing Record 2 of Set 8 | victoria
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | mersing
# Processing Record 5 of Set 8 | watertown
# Processing Record 6 of Set 8 | pakxan
# Processing Record 7 of Set 8 | beneditinos
# Processing Record 8 of Set 8 | makakilo city
# Processing Record 9 of Set 8 | mapimi
# Processing Record 10 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 11 of Set 8 | drumheller
# Processing Record 12 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 14 of Set 8 | terra boa
# Processing Record 15 of Set 8 | port blair
# Processing Record 16 of Set 8 | lakselv
# Processing Record 17 of Set 8 | itarema
# Processing Record 18 of Set 8 | voyvozh
# Processing Record 19 of Set 8 | malaga
# Processing Record 20 of Set 8 | manacapuru
# Processing Record 21 of Set 8 | lufilufi
# Processing Record 22 of Set 8 | zhigansk
# Processing Record 23 of Set 8 | bardiyah
# Processing Record 24 of Set 8 | kontagora
# Processing Record 25 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 8 | baykit
# Processing Record 27 of Set 8 | ji-parana
# City not found. Skipping...
# Processing Record 28 of Set 8 | namatanai
# Processing Record 29 of Set 8 | balikpapan
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | lumberton
# Processing Record 32 of Set 8 | dzhebariki-khaya
# Processing Record 33 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 8 | aviles
# Processing Record 35 of Set 8 | sangar
# Processing Record 36 of Set 8 | speedway
# Processing Record 37 of Set 8 | sfantu gheorghe
# Processing Record 38 of Set 8 | ishigaki
# Processing Record 39 of Set 8 | cansahcab
# Processing Record 40 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 8 | maunabo
# Processing Record 42 of Set 8 | margate
# Processing Record 43 of Set 8 | barra dos coqueiros
# Processing Record 44 of Set 8 | iqaluit
# Processing Record 45 of Set 8 | houma
# Processing Record 46 of Set 8 | staroye drozhzhanoye
# Processing Record 47 of Set 8 | elliot lake
# Processing Record 48 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 8 | east grand rapids
# Processing Record 50 of Set 8 | puerto penasco
# Processing Record 1 of Set 9 | saint-leu
# Processing Record 2 of Set 9 | chardara
# Processing Record 3 of Set 9 | beloha
# Processing Record 4 of Set 9 | cristalina
# Processing Record 5 of Set 9 | verkhnyaya inta
# Processing Record 6 of Set 9 | arroyo
# Processing Record 7 of Set 9 | winnemucca
# Processing Record 8 of Set 9 | kruisfontein
# Processing Record 9 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | antofagasta
# Processing Record 11 of Set 9 | ankazoabo
# Processing Record 12 of Set 9 | chuy
# Processing Record 13 of Set 9 | peniche
# Processing Record 14 of Set 9 | de-kastri
# Processing Record 15 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 | camacha
# Processing Record 17 of Set 9 | moncton
# Processing Record 18 of Set 9 | saint-joseph
# Processing Record 19 of Set 9 | akureyri
# Processing Record 20 of Set 9 | gorontalo
# Processing Record 21 of Set 9 | mamallapuram
# Processing Record 22 of Set 9 | dimitrovgrad
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | belaya gora
# Processing Record 25 of Set 9 | rosario
# Processing Record 26 of Set 9 | coihaique
# Processing Record 27 of Set 9 | stendal
# Processing Record 28 of Set 9 | axim
# Processing Record 29 of Set 9 | ayorou
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | ngunguru
# Processing Record 32 of Set 9 | komsomolskoye
# Processing Record 33 of Set 9 | machico
# Processing Record 34 of Set 9 | opuwo
# Processing Record 35 of Set 9 | severobaykalsk
# Processing Record 36 of Set 9 | padang
# Processing Record 37 of Set 9 | arlit
# Processing Record 38 of Set 9 | tanout
# Processing Record 39 of Set 9 | deputatskiy
# Processing Record 40 of Set 9 | harrison
# Processing Record 41 of Set 9 | ario
# City not found. Skipping...
# Processing Record 42 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | markova
# Processing Record 45 of Set 9 | bulgan
# Processing Record 46 of Set 9 | hofn
# Processing Record 47 of Set 9 | san angelo
# Processing Record 48 of Set 9 | khandyga
# Processing Record 49 of Set 9 | zheleznodorozhnyy
# Processing Record 50 of Set 9 | alvorada
# Processing Record 1 of Set 10 | tambun
# Processing Record 2 of Set 10 | awbari
# Processing Record 3 of Set 10 | vytegra
# Processing Record 4 of Set 10 | airai
# Processing Record 5 of Set 10 | cedeno
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | muisne
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | kodiak
# Processing Record 10 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 10 | biak
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | ambulu
# Processing Record 14 of Set 10 | bagdarin
# Processing Record 15 of Set 10 | mahibadhoo
# Processing Record 16 of Set 10 | nemuro
# Processing Record 17 of Set 10 | fort walton beach
# Processing Record 18 of Set 10 | parkes
# Processing Record 19 of Set 10 | sao jose da coroa grande
# Processing Record 20 of Set 10 | altay
# Processing Record 21 of Set 10 | santa cruz del sur
# Processing Record 22 of Set 10 | dubrovnik
# Processing Record 23 of Set 10 | trairi
# Processing Record 24 of Set 10 | brinkovskaya
# Processing Record 25 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 26 of Set 10 | miri
# Processing Record 27 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | yambio
# Processing Record 29 of Set 10 | sudislavl
# Processing Record 30 of Set 10 | norilsk
# Processing Record 31 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 10 | brezovo
# Processing Record 33 of Set 10 | miranda
# Processing Record 34 of Set 10 | vuktyl
# Processing Record 35 of Set 10 | price
# Processing Record 36 of Set 10 | vila franca do campo
# Processing Record 37 of Set 10 | vestmannaeyjar
# Processing Record 38 of Set 10 | voi
# Processing Record 39 of Set 10 | terney
# Processing Record 40 of Set 10 | tezu
# Processing Record 41 of Set 10 | beringovskiy
# Processing Record 42 of Set 10 | mao
# Processing Record 43 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 10 | port macquarie
# Processing Record 45 of Set 10 | crvenka
# Processing Record 46 of Set 10 | mocuba
# Processing Record 47 of Set 10 | abonnema
# Processing Record 48 of Set 10 | mazyr
# Processing Record 49 of Set 10 | cacak
# Processing Record 50 of Set 10 | tarnos
# Processing Record 1 of Set 11 | birao
# Processing Record 2 of Set 11 | byron bay
# Processing Record 3 of Set 11 | havre-saint-pierre
# Processing Record 4 of Set 11 | borisoglebskiy
# Processing Record 5 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 6 of Set 11 | husavik
# Processing Record 7 of Set 11 | praia da vitoria
# Processing Record 8 of Set 11 | half moon bay
# Processing Record 9 of Set 11 | shitanjing
# Processing Record 10 of Set 11 | chaoyang
# Processing Record 11 of Set 11 | mazamari
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | nha trang
# Processing Record 14 of Set 11 | mayor pablo lagerenza
# Processing Record 15 of Set 11 | pendleton
# Processing Record 16 of Set 11 | rio grande
# Processing Record 17 of Set 11 | tagusao
# Processing Record 18 of Set 11 | bad wildungen
# Processing Record 19 of Set 11 | maxixe
# Processing Record 20 of Set 11 | murgab
# Processing Record 21 of Set 11 | nelson
# Processing Record 22 of Set 11 | buraydah
# Processing Record 23 of Set 11 | dolna banja
# City not found. Skipping...
# Processing Record 24 of Set 11 | hudiksvall
# Processing Record 25 of Set 11 | mandera
# Processing Record 26 of Set 11 | balingasay
# Processing Record 27 of Set 11 | miandrivazo
# Processing Record 28 of Set 11 | salatiga
# Processing Record 29 of Set 11 | yarovoye
# Processing Record 30 of Set 11 | gimli
# Processing Record 31 of Set 11 | limenaria
# Processing Record 32 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 11 | kaita
# Processing Record 34 of Set 11 | leninskoye
# Processing Record 35 of Set 11 | the valley
# Processing Record 36 of Set 11 | cuamba
# Processing Record 37 of Set 11 | tautira
# Processing Record 38 of Set 11 | bandarbeyla
# Processing Record 39 of Set 11 | salisbury
# Processing Record 40 of Set 11 | atar
# Processing Record 41 of Set 11 | kaeo
# Processing Record 42 of Set 11 | penha
# Processing Record 43 of Set 11 | ozernovskiy
# Processing Record 44 of Set 11 | sinnamary
# Processing Record 45 of Set 11 | jiayuguan
# Processing Record 46 of Set 11 | benguela
# Processing Record 47 of Set 11 | aden
# Processing Record 48 of Set 11 | mugur-aksy
# Processing Record 49 of Set 11 | estelle
# Processing Record 50 of Set 11 | gushikawa
# Processing Record 1 of Set 12 | camana
# Processing Record 2 of Set 12 | sabha
# Processing Record 3 of Set 12 | aksu
# Processing Record 4 of Set 12 | muzaffarabad
# Processing Record 5 of Set 12 | bathsheba
# Processing Record 6 of Set 12 | quatre cocos
# Processing Record 7 of Set 12 | kantang
# Processing Record 8 of Set 12 | laguna
# Processing Record 9 of Set 12 | amahai
# Processing Record 10 of Set 12 | vanimo
# Processing Record 11 of Set 12 | mandalgovi
# Processing Record 12 of Set 12 | avera
# Processing Record 13 of Set 12 | natalio
# Processing Record 14 of Set 12 | galbshtadt
# Processing Record 15 of Set 12 | najran
# Processing Record 16 of Set 12 | unguia
# Processing Record 17 of Set 12 | pangkalanbuun
# Processing Record 18 of Set 12 | valdivia
# Processing Record 19 of Set 12 | srandakan
# Processing Record 20 of Set 12 | aasiaat
# Processing Record 21 of Set 12 | pekan
# Processing Record 22 of Set 12 | fereydun kenar
# Processing Record 23 of Set 12 | challans
# Processing Record 24 of Set 12 | ismailia
# Processing Record 25 of Set 12 | kandrian
# Processing Record 26 of Set 12 | flin flon
# Processing Record 27 of Set 12 | batagay
# Processing Record 28 of Set 12 | visegrad
# Processing Record 29 of Set 12 | san cayetano
# Processing Record 30 of Set 12 | torgau
# Processing Record 31 of Set 12 | aleksandrovskoye
# Processing Record 32 of Set 12 | goulburn
# Processing Record 33 of Set 12 | tamala
# Processing Record 34 of Set 12 | nago
# Processing Record 35 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 36 of Set 12 | ola
# Processing Record 37 of Set 12 | chake chake
# Processing Record 38 of Set 12 | nishihara
# Processing Record 39 of Set 12 | balagansk
# Processing Record 40 of Set 12 | hervey bay
# Processing Record 41 of Set 12 | garowe
# Processing Record 42 of Set 12 | evensk
# Processing Record 43 of Set 12 | huallanca
# Processing Record 44 of Set 12 | portland
# Processing Record 45 of Set 12 | selty
# Processing Record 46 of Set 12 | ixtapa
# Processing Record 47 of Set 12 | lavrentiya
# Processing Record 48 of Set 12 | mizdah
# Processing Record 49 of Set 12 | maamba
# Processing Record 50 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 13 | tegh
# Processing Record 2 of Set 13 | broken hill
# Processing Record 3 of Set 13 | sola
# Processing Record 4 of Set 13 | grado
# Processing Record 5 of Set 13 | honiara
# Processing Record 6 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 7 of Set 13 | natal
# Processing Record 8 of Set 13 | galich
# Processing Record 9 of Set 13 | litovko
# Processing Record 10 of Set 13 | xuzhou
# Processing Record 11 of Set 13 | fort nelson
# Processing Record 12 of Set 13 | nelson bay
# Processing Record 13 of Set 13 | frome
# Processing Record 14 of Set 13 | tocopilla
# Processing Record 15 of Set 13 | arcachon
# Processing Record 16 of Set 13 | cururupu
# Processing Record 17 of Set 13 | lianran
# Processing Record 18 of Set 13 | quesnel
# Processing Record 19 of Set 13 | badarwas
# Processing Record 20 of Set 13 | hovd
# Processing Record 21 of Set 13 | kijang
# Processing Record 22 of Set 13 | bijie
# Processing Record 23 of Set 13 | adrar
# Processing Record 24 of Set 13 | ostersund
# Processing Record 25 of Set 13 | canutama
# Processing Record 26 of Set 13 | kalmunai
# Processing Record 27 of Set 13 | ilovlya
# Processing Record 28 of Set 13 | arcata
# Processing Record 29 of Set 13 | twentynine palms
# Processing Record 30 of Set 13 | yarmouth
# Processing Record 31 of Set 13 | athabasca
# Processing Record 32 of Set 13 | abu dhabi
# Processing Record 33 of Set 13 | penzance
# Processing Record 34 of Set 13 | borba
# Processing Record 35 of Set 13 | westport
# Processing Record 36 of Set 13 | mattru
# Processing Record 37 of Set 13 | bonavista
# Processing Record 38 of Set 13 | nortelandia
# Processing Record 39 of Set 13 | jaciara
# Processing Record 40 of Set 13 | erzin
# Processing Record 41 of Set 13 | sterling
# Processing Record 42 of Set 13 | dawei
# Processing Record 43 of Set 13 | tulun
# Processing Record 44 of Set 13 | borovichi
# Processing Record 45 of Set 13 | havoysund
# Processing Record 46 of Set 13 | valparaiso
# Processing Record 47 of Set 13 | kirakira
# Processing Record 48 of Set 13 | mackay
# Processing Record 49 of Set 13 | ossora
# Processing Record 50 of Set 13 | afyonkarahisar
# Processing Record 1 of Set 14 | shakawe
# Processing Record 2 of Set 14 | san juan
# Processing Record 3 of Set 14 | nizwa
# Processing Record 4 of Set 14 | masterton
# Processing Record 5 of Set 14 | taboc
# Processing Record 6 of Set 14 | juneau
# Processing Record 7 of Set 14 | aykhal
# Processing Record 8 of Set 14 | kavaratti
# Processing Record 9 of Set 14 | bukachacha
# Processing Record 10 of Set 14 | luang prabang
# Processing Record 11 of Set 14 | barcelos
# Processing Record 12 of Set 14 | polyarnyy
# Processing Record 13 of Set 14 | morrisburg
# Processing Record 14 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 15 of Set 14 | chemal
# Processing Record 16 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 17 of Set 14 | usinsk
# Processing Record 18 of Set 14 | bollnas
# Processing Record 19 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 14 | yichun
# Processing Record 21 of Set 14 | kigoma
# Processing Record 22 of Set 14 | gunnedah
# Processing Record 23 of Set 14 | wittstock
# Processing Record 24 of Set 14 | kamarion
# Processing Record 25 of Set 14 | port shepstone
# Processing Record 26 of Set 14 | lyman
# Processing Record 27 of Set 14 | camopi
# Processing Record 28 of Set 14 | taoudenni
# Processing Record 29 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 14 | igarka
# Processing Record 31 of Set 14 | ocean city
# Processing Record 32 of Set 14 | joshimath
# Processing Record 33 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 34 of Set 14 | kiama
# Processing Record 35 of Set 14 | andra
# Processing Record 36 of Set 14 | northam
# Processing Record 37 of Set 14 | aranos
# Processing Record 38 of Set 14 | calama
# Processing Record 39 of Set 14 | cap malheureux
# Processing Record 40 of Set 14 | charlottetown
# Processing Record 41 of Set 14 | chubbuck
# Processing Record 42 of Set 14 | hornepayne
# Processing Record 43 of Set 14 | soledade
# Processing Record 44 of Set 14 | dakar
# Processing Record 45 of Set 14 | murino
# Processing Record 46 of Set 14 | kot addu
# Processing Record 47 of Set 14 | saint-georges
# Processing Record 48 of Set 14 | bilma
# Processing Record 49 of Set 14 | sao miguel
# Processing Record 50 of Set 14 | samarai
# Processing Record 1 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 15 | la asuncion
# Processing Record 3 of Set 15 | porto velho
# Processing Record 4 of Set 15 | aquiraz
# Processing Record 5 of Set 15 | lydenburg
# Processing Record 6 of Set 15 | nantucket
# Processing Record 7 of Set 15 | yeniseysk
# Processing Record 8 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 15 | changde
# Processing Record 11 of Set 15 | ayan
# Processing Record 12 of Set 15 | barma
# Processing Record 13 of Set 15 | iwaki
# Processing Record 14 of Set 15 | puerto del rosario
# Processing Record 15 of Set 15 | portree
# Processing Record 16 of Set 15 | galle
# Processing Record 17 of Set 15 | itarsi
# Processing Record 18 of Set 15 | laramie
# Processing Record 19 of Set 15 | burica
# City not found. Skipping...
# Processing Record 20 of Set 15 | auki
# Processing Record 21 of Set 15 | duartina
# Processing Record 22 of Set 15 | santiago
# Processing Record 23 of Set 15 | khandbari
# Processing Record 24 of Set 15 | sakakah
# Processing Record 25 of Set 15 | cabadiangan
# Processing Record 26 of Set 15 | mporokoso
# Processing Record 27 of Set 15 | ballina
# Processing Record 28 of Set 15 | marystown
# Processing Record 29 of Set 15 | la jagua del pilar
# Processing Record 30 of Set 15 | solnechnyy
# Processing Record 31 of Set 15 | ninghai
# Processing Record 32 of Set 15 | ballstad
# City not found. Skipping...
# Processing Record 33 of Set 15 | karasburg
# Processing Record 34 of Set 15 | clive
# Processing Record 35 of Set 15 | salalah
# Processing Record 36 of Set 15 | salamiyah
# Processing Record 37 of Set 15 | santa isabel do rio negro
# Processing Record 38 of Set 15 | kamaishi
# Processing Record 39 of Set 15 | niono
# Processing Record 40 of Set 15 | estepona
# Processing Record 41 of Set 15 | waspan
# Processing Record 42 of Set 15 | codrington
# Processing Record 43 of Set 15 | schwedt
# Processing Record 44 of Set 15 | goderich
# Processing Record 45 of Set 15 | strezhevoy
# Processing Record 46 of Set 15 | waitati
# Processing Record 47 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 15 | gat
# Processing Record 49 of Set 15 | kudahuvadhoo
# Processing Record 50 of Set 15 | acapulco
# Processing Record 1 of Set 16 | pajapan
# Processing Record 2 of Set 16 | konstantinovka
# Processing Record 3 of Set 16 | neuquen
# Processing Record 4 of Set 16 | caceres
# Processing Record 5 of Set 16 | chiang khong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mombetsu  44.3525  143.3525     38.17        86         100        8.95
# 1      Oistins  13.0667  -59.5333     82.49        65          40       19.57
# 2      Terrace  54.5163 -128.6035     30.11        37          20        6.91
# 3  Yellowknife  62.4560 -114.3525     -8.45        70          75       13.80
# 4       Jijiga   9.3500   42.8000     59.70        46          45       10.25
# 5    Cape Town -33.9258   18.4232     72.91        68           0        5.75
# 6      Rikitea -23.1203 -134.9692     73.89        78          56        7.87
# 7    Berezanka  46.8526   31.3880     42.69        86         100       11.03
# 8  Keti Bandar  24.1447   67.4497     75.15        59           4        7.27
# 9        Alofi -19.0595 -169.9187     80.49        69          75       17.27
#
#   Country Current Description
# 0      JP          light rain
# 1      BB    scattered clouds
# 2      CA          few clouds
# 3      CA       broken clouds
# 4      ET    scattered clouds
# 5      ZA           clear sky
# 6      PF          light rain
# 7      UA     overcast clouds
# 8      PK           clear sky
# 9      NU       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mombetsu      JP  44.3525  143.3525     38.17        86         100
# 1      Oistins      BB  13.0667  -59.5333     82.49        65          40
# 2      Terrace      CA  54.5163 -128.6035     30.11        37          20
# 3  Yellowknife      CA  62.4560 -114.3525     -8.45        70          75
# 4       Jijiga      ET   9.3500   42.8000     59.70        46          45
# 5    Cape Town      ZA -33.9258   18.4232     72.91        68           0
# 6      Rikitea      PF -23.1203 -134.9692     73.89        78          56
# 7    Berezanka      UA  46.8526   31.3880     42.69        86         100
# 8  Keti Bandar      PK  24.1447   67.4497     75.15        59           4
# 9        Alofi      NU -19.0595 -169.9187     80.49        69          75
#
#    Wind Speed Current Description
# 0        8.95          light rain
# 1       19.57    scattered clouds
# 2        6.91          few clouds
# 3       13.80       broken clouds
# 4       10.25    scattered clouds
# 5        5.75           clear sky
# 6        7.87          light rain
# 7       11.03     overcast clouds
# 8        7.27           clear sky
# 9       17.27       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
